# %%
# Out:
# 📚 Bibliotecas de Machine Learning importadas com sucesso!
# ✅ XGBoost disponível: True

# %%
# Out:
# 📊 CARREGAMENTO E PREPARAÇÃO DOS DADOS PARA ML
# ...
# ✅ Dataset preparado para ML:
#    • Forma: (610, 13)
#    • Variáveis alvo: ['Pluviosidade', 'Vazão', 'TempAr', 'pH', 'OD', 'Turbidez', 'CondEsp']
#    • Features: ['Ano', 'Mes', 'Trimestre', 'CIDADE_encoded', 'Periodo_encoded', 'Curso_encoded']
#    • Registros válidos: 610
#
# 📊 Distribuição dos dados:
#        Pluviosidade    Vazão  TempAr      pH      OD  Turbidez   CondEsp
# count        610.00   610.00  610.00  610.00  610.00    610.00    610.00
# mean         109.44    80.14   30.41    6.90    7.04     44.05    202.49
# std          125.29   122.46    3.73    4.20    5.04     50.48   1846.83
# min            0.00     6.89    6.83    0.00    0.00      0.68      0.00
# 25%           11.55    34.11   28.00    6.05    6.09     19.30     27.82
# 50%           52.14    44.45   30.00    6.74    7.00     28.30     57.70
# 75%          182.64    73.36   32.08    7.22    7.51     48.12     79.55
# ...

# %%
# Out:
# 🔍 ANÁLISE EXPLORATÓRIA PARA ML
# ...
# 📊 Análise de Valores Nulos:
#   Pluviosidade: 0 nulos (0.0%)
#   Vazão: 0 nulos (0.0%)
#   TempAr: 0 nulos (0.0%)
#   pH: 0 nulos (0.0%)
#   OD: 0 nulos (0.0%)
#   Turbidez: 0 nulos (0.0%)
#   CondEsp: 0 nulos (0.0%)
#
# ✅ Variáveis com boa qualidade para ML (< 20% nulos): ['Pluviosidade', 'Vazão', 'TempAr', 'pH', 'OD', 'Turbidez', 'CondEsp']

# %%
# Out:
# ✅ Função de treinamento e comparação criada!

# %%
# Out:
# 🚀 INICIANDO TREINAMENTO DE MODELOS
# ...
#
# ...
# 🎯 TREINANDO MODELOS PARA: Pluviosidade
# ...
# 📊 Dados disponíveis: 610 registros
# 📊 Features: 6 variáveis
#
# 🤖 TREINANDO MODELOS PARA: Pluviosidade
# ...
# 📈 Treinando Linear Regression...
# 🌲 Treinando Random Forest...
# 🎯 Treinando Support Vector Machine...
# 🧠 Treinando Neural Network...
# ⚡ Treinando XGBoost...
#
# 📊 RESULTADOS PARA Pluviosidade:
#                        R²      RMSE
# Random Forest      0.8387   51.7690
# XGBoost            0.8356   52.2734
# Neural Network     0.6431   77.0150
# Linear Regression  0.4559   95.0823
# SVM                0.0513  125.5546
#
# 🏆 MELHOR MODELO: Random Forest
#    R² Score: 0.8387
#    RMSE: 51.7690
# ✅ Pluviosidade - Treinamento concluído!
#
# ...
# 🎯 TREINANDO MODELOS PARA: Vazão
# ...
# 📊 Dados disponíveis: 610 registros
# 📊 Features: 6 variáveis
#
# 🤖 TREINANDO MODELOS PARA: Vazão
# ...
# 📈 Treinando Linear Regression...
# 🌲 Treinando Random Forest...
# 🎯 Treinando Support Vector Machine...
# ...

# %%
# Out:
# 🏆 RESUMO DOS MELHORES MODELOS
# ...
# 📊 Ranking dos Melhores Modelos:
#        Variável      Melhor Modelo  R² Score      RMSE
# 0  Pluviosidade      Random Forest    0.8387   51.7690
# 2        TempAr            XGBoost    0.3550    2.6058
# 1         Vazão      Random Forest    0.1514   96.2115
# 3            pH                SVM    0.1119    1.1585
# 5      Turbidez  Linear Regression    0.0480   43.6886
# 4            OD                SVM   -0.0015    1.4898
# 6       CondEsp                SVM   -0.0168  280.2241
# 📈 ANÁLISE DOS RESULTADOS:
#    • Melhor performance geral: Pluviosidade (R² = 0.8387)
#    • Pior performance geral: CondEsp (R² = -0.0168)
#    • Modelo mais frequente: SVM (3 vezes)
#    • R² médio: 0.2124
#    • RMSE médio: 68.1639

# %%
# Out:
# 📈 ANÁLISE DE SÉRIES TEMPORAIS COM ARIMA
# ...
#
# 🔍 ANÁLISE ARIMA PARA: Pluviosidade
# --------------------------------------------------
# 📊 Estatísticas da série:
#    • Média: 109.4380
#    • Desvio padrão: 125.2924
#    • Coeficiente de variação: 114.49%
#
# 📈 Modelo ARIMA(1,1,1) ajustado:
#    • AIC: 7053.20
#    • BIC: 7066.44
#    • Log-Likelihood: -3523.60
#
# 🔮 Previsões para os próximos 5 períodos:
#    Período 1: 37.1516
#    Período 2: 63.1889
#    Período 3: 83.0897
#    Período 4: 98.3002
#    Período 5: 109.9258
#
# 🔍 ANÁLISE ARIMA PARA: Vazão
# --------------------------------------------------
# 📊 Estatísticas da série:
#    • Média: 80.1407
#    • Desvio padrão: 122.4566
#    • Coeficiente de variação: 152.80%
#
# 📈 Modelo ARIMA(1,1,1) ajustado:
#    • AIC: 7583.68
#    • BIC: 7596.92
#    • Log-Likelihood: -3788.84
#
# 🔮 Previsões para os próximos 5 períodos:
#    Período 1: 102.7531
#    Período 2: 108.2956
#    Período 3: 108.7607
#    Período 4: 108.7997
# ...

# %%
# Out:
# 🔧 VALIDAÇÃO CRUZADA E OTIMIZAÇÃO DE HIPERPARÂMETROS
# ...
#
# ⚙️ OTIMIZANDO HIPERPARÂMETROS PARA: Pluviosidade
# ------------------------------------------------------------
# 🌲 Otimizando Random Forest...
#    ✅ Melhor R²: 0.8300
#    ✅ Melhores parâmetros: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 🎯 Otimizando SVM...
#    ✅ Melhor R²: 0.6607
#    ✅ Melhores parâmetros: {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# ⚡ Otimizando XGBoost...
#    ✅ Melhor R²: 0.8204
#    ✅ Melhores parâmetros: {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8}
#
# 🔄 Validação Cruzada...
#    Random Forest: CV R² = 0.8243 ± 0.0305
#    SVM: CV R² = 0.6598 ± 0.0277
#    XGBoost: CV R² = 0.8755 ± 0.0264
#
# ⚙️ OTIMIZANDO HIPERPARÂMETROS PARA: TempAr
# ------------------------------------------------------------
# 🌲 Otimizando Random Forest...
#    ✅ Melhor R²: 0.3473
# ...

# %%
# Out:
# 🔮 PREVISÕES FUTURAS COM OS MELHORES MODELOS
# ...
#
# 🔮 PREVISÕES FUTURAS PARA: Pluviosidade
# --------------------------------------------------
# 📊 Performance no teste:
#    • R² Score: 0.8387
#    • RMSE: 51.7690
#
# 🔮 Previsões para os próximos 5 anos:
#
# 📅 Previsões mensais:
#
#    2025:
#      2025-01: 311.5286
#      2025-02: 257.3605
#      2025-03: 373.8639
#      2025-04: 303.7459
#      2025-05: 228.5334
#      2025-06: 46.9133
#      2025-07: 32.0941
#      2025-08: 12.3454
#      2025-09: 17.8137
#      2025-10: 40.4316
#      2025-11: 56.3655
#      2025-12: 238.0856
#
#    2026:
#      2026-01: 311.5286
#      2026-02: 257.3605
#      2026-03: 373.8639
#      2026-04: 303.7459
#      2026-05: 228.5334
#      2026-06: 46.9133
#      2026-07: 32.0941
#      2026-08: 12.3454
#      2026-09: 17.8137
#      2026-10: 40.4316
#      2026-11: 56.3655
#      2026-12: 238.0856
#
#    2027:
#      2027-01: 311.5286
#      2027-02: 257.3605
#      2027-03: 373.8639
# ...

# %%
# Out:
# 🔍 ANÁLISE DE IMPORTÂNCIA DAS FEATURES
# ...
#
# 🔍 IMPORTÂNCIA DAS FEATURES PARA: Pluviosidade
# --------------------------------------------------
# 📊 Ranking de Importância das Features:
#    Mes: 0.6916
#    Ano: 0.1519
#    CIDADE_encoded: 0.1208
#    Trimestre: 0.0229
#    Curso_encoded: 0.0118
#    Periodo_encoded: 0.0010
# 🔍 IMPORTÂNCIA DAS FEATURES PARA: TempAr
# --------------------------------------------------
# 📊 Ranking de Importância das Features:
#    Ano: 0.4600
#    CIDADE_encoded: 0.2845
#    Mes: 0.1930
#    Trimestre: 0.0384
#    Curso_encoded: 0.0144
#    Periodo_encoded: 0.0096
# 🔍 IMPORTÂNCIA DAS FEATURES PARA: Vazão
# --------------------------------------------------
# 📊 Ranking de Importância das Features:
#    CIDADE_encoded: 0.3407
#    Ano: 0.3162
#    Mes: 0.2592
#    Trimestre: 0.0388
#    Curso_encoded: 0.0320
#    Periodo_encoded: 0.0130
# 📊 RESUMO GERAL DA IMPORTÂNCIA DAS FEATURES
# ...
# 📈 Importância Média das Features:
#    Mes: 0.3813
#    Ano: 0.3094
# ...

# %%
# Out:
# 📋 RELATÓRIO FINAL E CONCLUSÕES
# ...
# 📊 RESUMO EXECUTIVO
# ------------------------------
# ✅ Variáveis analisadas: 7
# ✅ Modelos testados: 5
# ✅ R² médio: 0.2124
# ✅ Período dos dados: 1992-2024
#
# 🏆 TOP 3 MELHORES MODELOS:
# ------------------------------
# 1. Pluviosidade: Random Forest (R² = 0.8387)
# 2. Vazão: Random Forest (R² = 0.1514)
# 3. TempAr: XGBoost (R² = 0.3550)
#
# 🔮 PREVISÕES FUTURAS (Médias Anuais):
# ----------------------------------------
# • Pluviosidade:
#   2020: 159.9235
#   2021: 159.9235
#   2022: 159.9235
# • TempAr:
#   2020: 34.0271
#   2021: 34.0271
#   2022: 34.0271
# • Vazão:
#   2020: 379.7921
#   2021: 379.7921
#   2022: 379.7921
#
# 🔍 FEATURES MAIS IMPORTANTES:
# -----------------------------------
# 1. Ano: 0.3094
# 2. Mes: 0.3813
# 3. Trimestre: 0.0334
# 🎯 CONCLUSÕES PRINCIPAIS:
# ...
# 1. ✅ Machine Learning é viável para previsão de variáveis ambientais
# 2. ✅ Random Forest e XGBoost apresentaram melhor performance geral
# ...
